# %% [markdown]
# dataset_name= ****Mobile usage behavioral analysis****

# %% [markdown]
# This dataset provides insights into the daily mobile usage patterns of 1,000 users, covering aspects such as screen time, app usage, and user engagement across different app categories.
#
# It includes a diverse range of users based on age, gender, and location.
#
# The data focuses on total app usage, time spent on social media, productivity, and gaming apps, along with overall screen time.
#
# This information is valuable for understanding behavioral trends and app usage preferences, making it useful for app developers, marketers, and UX researchers.
#
# This dataset is useful for analyzing mobile engagement, app usage habits, and the impact of demographic factors on mobile behavior. It can help identify trends for marketing, app development, and user experience optimization.

# %% [markdown]
# Objective

# %% [markdown]
# This dataset enables a deeper understanding of mobile user behavior and app engagement across different demographics.
#
# Key outcomes include insights into app usage preferences, daily screen time habits, and the impact of age, gender, and location on mobile behavior.
#
# This analysis can help identify patterns for improving user experience, tailoring marketing strategies, and optimizing app development for different user segments

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("C:\\Users\\mohin\\Downloads\\mobile_usage_behavioral_analysis.csv")

# %%
dataset
# Out:
#      User_ID  Age  Gender  Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# 0          1   56    Male                   2.61                     7.15
# 1          2   46    Male                   2.13                    13.79
# 2          3   32  Female                   7.28                     4.50
# 3          4   25  Female                   1.20                     6.29
# 4          5   38    Male                   6.31                    12.59
# ..       ...  ...     ...                    ...                      ...
# 995      996   41  Female                   3.58                    12.46
# 996      997   32    Male                   9.65                    10.51
# 997      998   46  Female                  11.68                    10.06
# 998      999   25    Male                   3.89                    10.78
# 999     1000   22  Female                   3.99                     7.05
#
#      Number_of_Apps_Used  Social_Media_Usage_Hours  \
# ...

# %% [markdown]
# Features of dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   User_ID                       1000 non-null   int64
#  1   Age                           1000 non-null   int64
#  2   Gender                        1000 non-null   object
#  3   Total_App_Usage_Hours         1000 non-null   float64
#  4   Daily_Screen_Time_Hours       1000 non-null   float64
#  5   Number_of_Apps_Used           1000 non-null   int64
#  6   Social_Media_Usage_Hours      1000 non-null   float64
#  7   Productivity_App_Usage_Hours  1000 non-null   float64
#  8   Gaming_App_Usage_Hours        1000 non-null   float64
#  9   Location                      1000 non-null   object
# dtypes: float64(5), int64(3), object(2)
# memory usage: 78.3+ KB

# %%
dataset.describe(include="all")
# Out:
#             User_ID          Age Gender  Total_App_Usage_Hours  \
# count   1000.000000  1000.000000   1000            1000.000000
# unique          NaN          NaN      2                    NaN
# top             NaN          NaN   Male                    NaN
# freq            NaN          NaN    517                    NaN
# mean     500.500000    38.745000    NaN               6.405670
# std      288.819436    12.186734    NaN               3.134855
# min        1.000000    18.000000    NaN               1.000000
# 25%      250.750000    28.000000    NaN               3.590000
# 50%      500.500000    40.000000    NaN               6.455000
# 75%      750.250000    50.000000    NaN               9.122500
# max     1000.000000    59.000000    NaN              11.970000
#
#         Daily_Screen_Time_Hours  Number_of_Apps_Used  \
# count               1000.000000           1000.00000
# unique                      NaN                  NaN
# ...

# %% [markdown]
# unique values

# %%
dataset.nunique()
# Out:
# User_ID                         1000
# Age                               42
# Gender                             2
# Total_App_Usage_Hours            672
# Daily_Screen_Time_Hours          705
# Number_of_Apps_Used               27
# Social_Media_Usage_Hours         437
# Productivity_App_Usage_Hours     432
# Gaming_App_Usage_Hours           443
# Location                           5
# dtype: int64

# %% [markdown]
# Visualization perfomed on this dataset

# %% [markdown]
# lets see the relationship between [Social_Media_Usage_Hours] and [Productivity_App_Usage_Hours] by using scatterplot

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="Social_Media_Usage_Hours", y="Productivity_App_Usage_Hours",
                hue="Location", #size="Gender" 
                palette="dark",
                sizes=(1, 8), linewidth=0,
                data=dataset)
plt.title("Relationship between hrs spend on social media and productivity app")
plt.xlabel("Social Media hrs")
plt.ylabel("Productivity App hrs")
plt.show()

# %% [markdown]
# lets see relation between Total_App_Usage_Hours and Daily_Screen_Time_Hours by relation plot(relplot)

# %%
plt.figure(figsize=(12,6))
sns.relplot(data=dataset,
    x="Total_App_Usage_Hours", y="Daily_Screen_Time_Hours",
    hue="Location", #size="Gender", 
            palette='dark')
plt.title("Relationship between total app usage hrs and daily screen time hours")
plt.xlabel("Total app usage hours")
plt.ylabel("Daily screen time hrs")
plt.show()

# %% [markdown]
# we will drop User_ID column because it is not necessary here

# %%
dataset=dataset.drop(columns=['User_ID'])

# %%
dataset
# Out:
#      Age  Gender  Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# 0     56    Male                   2.61                     7.15
# 1     46    Male                   2.13                    13.79
# 2     32  Female                   7.28                     4.50
# 3     25  Female                   1.20                     6.29
# 4     38    Male                   6.31                    12.59
# ..   ...     ...                    ...                      ...
# 995   41  Female                   3.58                    12.46
# 996   32    Male                   9.65                    10.51
# 997   46  Female                  11.68                    10.06
# 998   25    Male                   3.89                    10.78
# 999   22  Female                   3.99                     7.05
#
#      Number_of_Apps_Used  Social_Media_Usage_Hours  \
# 0                     24                      4.43
# 1                     18                      4.67
# ...

# %%
dataset.nunique()
# Out:
# Age                              42
# Gender                            2
# Total_App_Usage_Hours           672
# Daily_Screen_Time_Hours         705
# Number_of_Apps_Used              27
# Social_Media_Usage_Hours        437
# Productivity_App_Usage_Hours    432
# Gaming_App_Usage_Hours          443
# Location                          5
# dtype: int64

# %% [markdown]
# Histogram for age distribution

# %%
plt.figure(figsize=(10,6))
sns.histplot(x='Age',kde=True,bins=20,data=dataset,color='blue')
plt.title("Age Distribtuion by Histogram")
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Histogram for Number_of_Apps_Used distribution

# %%
plt.figure(figsize=(12,8))
sns.histplot(x='Number_of_Apps_Used',bins=20,kde=True,data=dataset,color='indigo')
plt.xlabel('Numbers of used apps')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Age',y='Location',data=dataset)
plt.title("Boxplot")
plt.xlabel('Age')
plt.ylabel('Location')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Total_App_Usage_Hours',y='Gender',data=dataset)
plt.title("Boxplot")
plt.xlabel('Total_App_Usage_Hours')
plt.ylabel('Gender')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x='Daily_Screen_Time_Hours',y='Gender',data=dataset)
plt.title("Boxplot")
plt.xlabel('Daily_Screen_Time_Hours')
plt.ylabel('Gender')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x='Number_of_Apps_Used',y='Gender',data=dataset)
plt.title("Boxplot")
plt.xlabel('Number_of_Apps_Used')
plt.ylabel('Gender')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.boxenplot(data=dataset, x="Gender", y="Age")
    #color="b", order=clarity_ranking, width_method="linear"
plt.title("Boxplot")
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %%
dataset.nunique()
# Out:
# Age                              42
# Gender                            2
# Total_App_Usage_Hours           672
# Daily_Screen_Time_Hours         705
# Number_of_Apps_Used              27
# Social_Media_Usage_Hours        437
# Productivity_App_Usage_Hours    432
# Gaming_App_Usage_Hours          443
# Location                          5
# dtype: int64

# %%
plt.figure(figsize=(9,6))
sns.swarmplot(data=dataset, x="Location", y="Number_of_Apps_Used",hue="Gender")
plt.show()

# %%
plt.figure(figsize=(10,12))
sns.violinplot(hue='Location',y='Total_App_Usage_Hours',data=dataset,palette='dark')
plt.title("Total app usage distribution")
plt.xlabel("Loaction")
plt.ylabel("Total app usage hrs")
plt.show()

# %% [markdown]
# ***Heat map***

# %% [markdown]
# *****Label Encoding*****

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           1000 non-null   int64
#  1   Gender                        1000 non-null   object
#  2   Total_App_Usage_Hours         1000 non-null   float64
#  3   Daily_Screen_Time_Hours       1000 non-null   float64
#  4   Number_of_Apps_Used           1000 non-null   int64
#  5   Social_Media_Usage_Hours      1000 non-null   float64
#  6   Productivity_App_Usage_Hours  1000 non-null   float64
#  7   Gaming_App_Usage_Hours        1000 non-null   float64
#  8   Location                      1000 non-null   object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 70.4+ KB

# %%
from sklearn.preprocessing import LabelEncoder
categorical_columns=['Gender','Location']
labelencoder=LabelEncoder()
for column in categorical_columns:
    dataset[column]=labelencoder.fit_transform(dataset[column])

# %%
dataset
# Out:
#      Age  Gender  Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# 0     56       1                   2.61                     7.15
# 1     46       1                   2.13                    13.79
# 2     32       0                   7.28                     4.50
# 3     25       0                   1.20                     6.29
# 4     38       1                   6.31                    12.59
# ..   ...     ...                    ...                      ...
# 995   41       0                   3.58                    12.46
# 996   32       1                   9.65                    10.51
# 997   46       0                  11.68                    10.06
# 998   25       1                   3.89                    10.78
# 999   22       0                   3.99                     7.05
#
#      Number_of_Apps_Used  Social_Media_Usage_Hours  \
# 0                     24                      4.43
# 1                     18                      4.67
# ...

# %%
corr_matrix=dataset.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# *****Regression Analysis*****

# %%
x=dataset.drop(columns=['Age'])
y=dataset['Age']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Linear Regression Prediction

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

lr=LinearRegression()
lr.fit(x_train,y_train)
y_predlr_test=lr.predict(x_test)
y_predlr_train=lr.predict(x_train)

lr_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predlr_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predlr_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predlr_test),
           'Test R Squared':r2_score(y_test,y_predlr_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predlr_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predlr_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predlr_train),
           'Train R Squared':r2_score(y_train,y_predlr_train)}
print(lr_metrics)
# Out:
# {'Test Mean Squared Error': 151.29770810321463, 'Test Root Mean Squared Error': 12.300313333538078, 'Test Mean Absolute Error': 10.877211841302087, 'Test R Squared': -0.023770602237034533, 'Train Mean Squared Error': 147.25265247923588, 'Train Root Mean Squared Error': 12.134770392522302, 'Train Mean Absolute Error': 10.456374634039388, 'Train R Squared': 0.0084914112251252}

# %% [markdown]
# Multiple Regression Prediction

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

mlr=LinearRegression()
mlr.fit(x_train,y_train)
y_predmlr_test=mlr.predict(x_test)
y_predmlr_train=mlr.predict(x_train)

mlr_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predmlr_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predmlr_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predmlr_test),
           'Test R Squared':r2_score(y_test,y_predmlr_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predmlr_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predmlr_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predmlr_train),
           'Train R Squared':r2_score(y_train,y_predmlr_train)}
print(mlr_metrics)
# Out:
# {'Test Mean Squared Error': 151.29770810321463, 'Test Root Mean Squared Error': 12.300313333538078, 'Test Mean Absolute Error': 10.877211841302087, 'Test R Squared': -0.023770602237034533, 'Train Mean Squared Error': 147.25265247923588, 'Train Root Mean Squared Error': 12.134770392522302, 'Train Mean Absolute Error': 10.456374634039388, 'Train R Squared': 0.0084914112251252}

# %% [markdown]
# Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
y_preddt_test=dt.predict(x_test)
y_preddt_train=dt.predict(x_train)

dt_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_preddt_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_preddt_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_preddt_test),
           'Test R Squared':r2_score(y_test,y_preddt_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_preddt_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_preddt_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_preddt_train),
           'Train R Squared':r2_score(y_train,y_preddt_train)}
print(dt_metrics)
# Out:
# {'Test Mean Squared Error': 254.665, 'Test Root Mean Squared Error': 15.95822671852985, 'Test Mean Absolute Error': 12.835, 'Test R Squared': -0.7232153988798913, 'Train Mean Squared Error': 0.0, 'Train Root Mean Squared Error': 0.0, 'Train Mean Absolute Error': 0.0, 'Train R Squared': 1.0}

# %% [markdown]
# Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
y_predgb_test=gb.predict(x_test)
y_predgb_train=gb.predict(x_train)

gb_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predgb_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predgb_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predgb_test),
           'Test R Squared':r2_score(y_test,y_predgb_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predgb_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predgb_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predgb_train),
           'Train R Squared':r2_score(y_train,y_predgb_train)}
print(gb_metrics)
# Out:
# {'Test Mean Squared Error': 160.6430894985315, 'Test Root Mean Squared Error': 12.674505493254225, 'Test Mean Absolute Error': 10.961057561658231, 'Test R Squared': -0.08700703099173457, 'Train Mean Squared Error': 93.91861996655516, 'Train Root Mean Squared Error': 9.691161951311884, 'Train Mean Absolute Error': 8.188261524432463, 'Train R Squared': 0.3676099087189352}

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_predrf_test=rf.predict(x_test)
y_predrf_train=rf.predict(x_train)

rf_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predrf_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predrf_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predrf_test),
           'Test R Squared':r2_score(y_test,y_predrf_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predrf_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predrf_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predrf_train),
           'Train R Squared':r2_score(y_train,y_predrf_train)}
print(rf_metrics)
# Out:
# {'Test Mean Squared Error': 160.196436, 'Test Root Mean Squared Error': 12.656873073551777, 'Test Mean Absolute Error': 11.14, 'Test R Squared': -0.08398470681435222, 'Train Mean Squared Error': 22.171253375000003, 'Train Root Mean Squared Error': 4.708636041891538, 'Train Mean Absolute Error': 3.9847875, 'Train R Squared': 0.8507124471097982}

# %% [markdown]
# XG Boost

# %%
from xgboost import XGBRegressor
#from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

xgb=XGBRegressor()
xgb.fit(x_train,y_train)
y_predxgb_test=xgb.predict(x_test)
y_predxgb_train=xgb.predict(x_train)

xgb_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predxgb_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predxgb_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predxgb_test),
           'Test R Squared':r2_score(y_test,y_predxgb_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predxgb_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predxgb_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predxgb_train),
           'Train R Squared':r2_score(y_train,y_predxgb_train)}
print(xgb_metrics)
# Out:
# {'Test Mean Squared Error': 188.52232443110952, 'Test Root Mean Squared Error': 13.730343201504816, 'Test Mean Absolute Error': 11.882088232040406, 'Test R Squared': -0.2756545755887878, 'Train Mean Squared Error': 0.6143961876468347, 'Train Root Mean Squared Error': 0.7838342858326846, 'Train Mean Absolute Error': 0.5464026880264282, 'Train R Squared': 0.9958630348132556}
